# %% [markdown]
# f0b970f706ba8babb0bb582a384964d8b508

# %%
import csv
import requests
import xml.etree.ElementTree as ET
import time
from tinydb import TinyDB, Query
import os
import sys

# 配置您的电子邮件（NCBI 要求提供）
EMAIL = "lhua0420@gmail.com"  # 请替换为您的有效电子邮件地址

# 如果您有 NCBI 的 API Key，可以在这里添加
API_KEY = "f0b970f706ba8babb0bb582a384964d8b508"  # 可选，若无则留空

# 输入和输出 CSV 文件路径
INPUT_CSV = "./maude_papers.csv"
OUTPUT_CSV = "./maude_papers_output.csv"

# 初始化 TinyDB 数据库
db = TinyDB('articles.json')

# NCBI E-utilities 基础 URL
EUTILS_BASE_URL = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/"

# 函数：标准化字段名（去除空格、BOM并转换为小写）
def normalize_fieldnames(fieldnames):
    return [field.replace('\ufeff', '').strip().lower() for field in fieldnames]

# 函数：通过 PMID 获取摘要
def get_abstract(pmid):
    fetch_url = f"{EUTILS_BASE_URL}efetch.fcgi"
    params = {
        "db": "pubmed",
        "id": pmid,
        "rettype": "abstract",
        "retmode": "xml",
        "email": EMAIL
    }
    if API_KEY:
        params["api_key"] = API_KEY
    try:
        response = requests.get(fetch_url, params=params)
        response.raise_for_status()
        root = ET.fromstring(response.text)
        # 查找摘要文本
        abstract_text = ""
        for abstract in root.findall(".//Abstract/AbstractText"):
            label = abstract.attrib.get('Label')
            text = abstract.text if abstract.text else ""
            if label:
                abstract_text += f"{label}: {text} "
            else:
                abstract_text += f"{text} "
        abstract_text = abstract_text.strip()
        return abstract_text if abstract_text else "No Abstract Available"
    except Exception as e:
        print(f"Error fetching abstract for PMID {pmid}: {e}")
        return "Error Fetching Abstract"

# 函数：通过标题搜索并获取摘要
def get_abstract_by_title(title):
    search_url = f"{EUTILS_BASE_URL}esearch.fcgi"
    search_params = {
        "db": "pubmed",
        "term": title,
        "retmode": "xml",
        "email": EMAIL
    }
    if API_KEY:
        search_params["api_key"] = API_KEY
    try:
        response = requests.get(search_url, params=search_params)
        response.raise_for_status()
        root = ET.fromstring(response.text)
        # 获取第一个匹配的 PMID
        id_list = root.find(".//IdList")
        if id_list is not None:
            first_id = id_list.find("Id")
            if first_id is not None and first_id.text:
                # 使用该 PMID 获取摘要
                abstract = get_abstract(first_id.text)
                if abstract != "No Abstract Available":
                    print(f"Abstract found by title search for Title: '{title}' using PMID: {first_id.text}")
                return abstract
        return "No Abstract Available"
    except Exception as e:
        print(f"Error fetching abstract by title '{title}': {e}")
        return "Error Fetching Abstract by Title"

# 函数：通过 PMID 获取全文链接（PMC）
def get_fulltext_link(pmid):
    elink_url = f"{EUTILS_BASE_URL}elink.fcgi"
    params = {
        "dbfrom": "pubmed",
        "db": "pmc",
        "id": pmid,
        "retmode": "xml",
        "email": EMAIL
    }
    if API_KEY:
        params["api_key"] = API_KEY
    try:
        response = requests.get(elink_url, params=params)
        response.raise_for_status()
        root = ET.fromstring(response.text)
        # 查找 PMC ID
        pmc_id = None
        for linkset in root.findall(".//LinkSet"):
            for link in linkset.findall(".//Link"):
                if link.attrib.get('DbTo') == 'pmc':
                    pmc_id = link.find('Id').text
                    break
        if pmc_id:
            return f"https://www.ncbi.nlm.nih.gov/pmc/articles/PMC{pmc_id}/"
        else:
            return "No Full Text Available"
    except Exception as e:
        print(f"Error fetching full-text link for PMID {pmid}: {e}")
        return "Error Fetching Full Text Link"

def main():
    # 检查输出CSV是否存在，并收集已处理的PMID
    processed_pmids = set()
    if os.path.exists(OUTPUT_CSV):
        with open(OUTPUT_CSV, mode='r', encoding='utf-8') as outfile:
            reader = csv.DictReader(outfile)
            for row in reader:
                pmid = row.get('PMID', '').strip()
                if pmid:
                    # 检查是否已经有摘要和全文链接且未标记错误
                    if row.get('Abstract') not in ["Error Fetching Abstract", "Missing PMID", "Error Fetching Abstract by Title"] and \
                       row.get('FullTextLink') not in ["Error Fetching Full Text Link", "Missing PMID"]:
                        processed_pmids.add(pmid)

    # 读取输入 CSV
    try:
        with open(INPUT_CSV, mode='r', encoding='utf-8-sig') as infile:
            reader = csv.DictReader(infile)
            # 打印实际读取到的字段名
            print(f"Original CSV Headers: {reader.fieldnames}")
            # 标准化字段名
            normalized_headers = normalize_fieldnames(reader.fieldnames)
            print(f"Normalized CSV Headers: {normalized_headers}")
            # 检查是否包含必要的字段
            expected_fields = ['pmid', 'title', 'publication date']
            missing_fields = [field for field in expected_fields if field not in normalized_headers]
            if missing_fields:
                print(f"Error: Missing expected fields in CSV headers: {', '.join(missing_fields)}")
                print(f"Available headers: {reader.fieldnames}")
                return
            # 创建字段映射（标准化后的字段名 -> 原始字段名）
            header_mapping = {field.replace('\ufeff', '').strip().lower(): field for field in reader.fieldnames}
            # 获取实际字段名
            pmid_field = header_mapping['pmid']
            title_field = header_mapping['title']
            pubdate_field = header_mapping['publication date']
            # 添加新的字段名
            fieldnames = reader.fieldnames + ['Abstract', 'FullTextLink']
            articles = list(reader)
    except FileNotFoundError:
        print(f"Error: File '{INPUT_CSV}' not found.")
        return
    except Exception as e:
        print(f"Error reading '{INPUT_CSV}': {e}")
        return

    # 处理的文章列表
    to_process = []
    for article in articles:
        pmid = article.get(pmid_field, '').strip()
        if not pmid or pmid in processed_pmids:
            continue
        to_process.append(article)

    total_to_process = len(to_process)
    print(f"Total articles to process: {total_to_process}")

    # 如果没有需要处理的文章，退出
    if total_to_process == 0:
        print("No articles need processing. Exiting.")
        return

    # 打开输出 CSV文件，准备追加模式
    write_header = not os.path.exists(OUTPUT_CSV)
    with open(OUTPUT_CSV, mode='a', encoding='utf-8', newline='') as outfile:
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)
        if write_header:
            writer.writeheader()
        batch_count = 0
        for index, article in enumerate(to_process, start=1):
            pmid = article.get(pmid_field, '').strip()
            title = article.get(title_field, '').strip()
            publication_date = article.get(pubdate_field, '').strip()

            # 调试输出
            print(f"Processing PMID={pmid}, Title='{title}', Publication Date='{publication_date}'")

            # 获取摘要
            abstract = get_abstract(pmid)
            if abstract == "No Abstract Available":
                # 通过标题搜索获取摘要
                abstract = get_abstract_by_title(title)
                if abstract == "No Abstract Available":
                    print(f"No abstract found for PMID {pmid} and Title '{title}'.")
            elif abstract.startswith("Error"):
                # 已经标记为错误，无需进一步操作
                pass

            # 获取全文链接
            fulltext_link = get_fulltext_link(pmid)

            # 检查并标记错误
            if abstract.startswith("Error"):
                article['Abstract'] = abstract
            else:
                article['Abstract'] = abstract

            if fulltext_link.startswith("Error"):
                article['FullTextLink'] = fulltext_link
            else:
                article['FullTextLink'] = fulltext_link

            # 将信息插入 TinyDB
            db.insert({
                'PMID': pmid,
                'Title': title,
                'Publication Date': publication_date,
                'Abstract': abstract,
                'FullTextLink': fulltext_link
            })

            # 写入输出 CSV
            writer.writerow(article)

            batch_count += 1

            # 每处理10篇文章，保存一次
            if batch_count % 10 == 0:
                outfile.flush()
                # TinyDB不需要显式调用flush()
                print(f"Processed {batch_count} articles. Data saved.")

            # 为避免触发速率限制，暂停一段时间
            time.sleep(0.34)  # 大约每秒 3 次请求

        # 处理完毕后，确保所有数据已保存
        outfile.flush()
        # TinyDB不需要显式调用flush()
        print(f"All {batch_count} articles have been processed and saved.")

    # 关闭数据库连接
    db.close()

if __name__ == "__main__":
    main()
# Out:
# Original CSV Headers: ['PMID', 'Title', 'Publication Date']
# Normalized CSV Headers: ['pmid', 'title', 'publication date']
# Total articles to process: 559
# Processing PMID=39318983, Title='Adverse Events Associated With 3 Vitrectomy Platforms Reported to the US FDA MAUDE Database.', Publication Date='Sep, 2024'
# No abstract found for PMID 39318983 and Title 'Adverse Events Associated With 3 Vitrectomy Platforms Reported to the US FDA MAUDE Database.'.
# Processing PMID=39311943, Title='Adverse events related to robotic-assisted knee arthroplasty: a cross-sectional study from the MAUDE database.', Publication Date='Sep, 2024'
# Processing PMID=39284394, Title='How Often Does Technology Fail in Robotic-Assisted Arthroplasty? A Comprehensive Analysis of a United States Food and Drug Administration Database.', Publication Date='Sep, 2024'
# Processing PMID=39281406, Title='Adverse Events of Femtosecond-Assisted Laser-Assisted In situ Keratomileusis: A Manufacturer and User Facility Device Experience Database Study.', Publication Date='Sep, 2024'
# Processing PMID=39276215, Title='Trends and incidence of reported events associated with ureteral stents: an analysis of the food and drug administration's manufacturer and user facility device experience (MAUDE) database.', Publication Date='Sep, 2024'
# Processing PMID=39216717, Title='Failure to treat ventricular tachycardia or ventricular fibrillation by implantable cardioverter-defibrillators.', Publication Date='Sep, 2024'
# Processing PMID=39208707, Title='Analysis of antibiotic resistant infections associated with hirudotherapy.', Publication Date='Aug, 2024'
# Processing PMID=39176609, Title='Developing a Generative AI-Powered Chatbot for Analyzing MAUDE Database.', Publication Date='Aug, 2024'
# Processing PMID=39176599, Title='A Data Pipeline for Enhancing Quality of MAUDE-Based Studies.', Publication Date='Aug, 2024'
# Processing PMID=39155262, Title='[Monitoring System of Medical Device Adverse Events in the US and Application of MAUDE Database in Medical Device Registration].', Publication Date='Aug, 2024'
# Processed 10 articles. Data saved.
# Processing PMID=39122507, Title='Keep an Eye on At-Home Devices: Energy-Based Acne and Anti-Aging Devices are Associated with Ocular Adverse Events in a Retrospective Analysis Using the MAUDE Database.', Publication Date='Aug, 2024'
# No abstract found for PMID 39122507 and Title 'Keep an Eye on At-Home Devices: Energy-Based Acne and Anti-Aging Devices are Associated with Ocular Adverse Events in a Retrospective Analysis Using the MAUDE Database.'.
# Processing PMID=39106679, Title='MAUDE database and Eustachian tube balloon dilation: Evaluation of adverse events and sales data.', Publication Date='Aug, 2024'
# Processing PMID=39099264, Title='Adverse events associated with robotic-assistance in total hip arthroplasty: an analysis based on the FDA MAUDE database.', Publication Date='Aug, 2024'
# Processing PMID=39067092, Title='Adverse events related to suction electrocautery devices in adenotonsillectomy: Analysis of the MAUDE database.', Publication Date='Jul, 2024'
# Processing PMID=39049270, Title='Enhancing MAUDE Database Utility by GPT-4 and Cause-Effect Visualization.', Publication Date='Jul, 2024'
# Processing PMID=38988303, Title='Complications Associated with AMBU™ Scope Use: An FDA MAUDE Analysis.', Publication Date='Jul, 2024'
# Processing PMID=38978283, Title='Catheter-related and clinical complications associated with QDOT MICROTM Ablation Catheter.', Publication Date='Jul, 2024'
# Processing PMID=38943447, Title='Comprehensive Analysis of Adverse Events Associated With Hypoglossal Nerve Stimulators: Insights From the MAUDE Database.', Publication Date='Jun, 2024'
# Processing PMID=38888060, Title='Are There Hidden Adverse Events in Hypoglossal Nerve Stimulation: Comparing Social Media and a Federal Database.', Publication Date='Jun, 2024'
# Processing PMID=38878940, Title='Clinical outcomes associated with an esophageal cooling device.', Publication Date='Jun, 2024'
# No abstract found for PMID 38878940 and Title 'Clinical outcomes associated with an esophageal cooling device.'.
# Processed 20 articles. Data saved.
# Processing PMID=38875724, Title='Characterizing the safety profile of vagus nerve stimulation devices for epilepsy from 21,448 manufacturer and user reports.', Publication Date='Jun, 2024'
# Processing PMID=38874875, Title='Postmarketing Reports of Incomplete Dosing-Related Complications with Self-Injected PCSK9 Inhibitors: A Descriptive Study and Disproportionality Analysis.', Publication Date='Jun, 2024'
# Processing PMID=38819199, Title='Reasons for Revision Surgery After Cervical Disk Arthroplasty Based on Medical Device Reports Maintained by the US Food and Drug Administration.', Publication Date='May, 2024'
# Processing PMID=38815918, Title='What is the MAUDE Database Telling us about 510(k) Authorization? Evaluation of Two Generations of Endovascular Arteriovenous Fistula Devices.', Publication Date='May, 2024'
# Processing PMID=38811504, Title='A Comprehensive Analysis of Reported Adverse Events and Device Failures Associated with Esophageal Self-Expandable Metal Stents: An FDA MAUDE Database Study.', Publication Date='May, 2024'
# Processing PMID=38810538, Title='Auditory brainstem implants: an analysis of adverse events in the MAUDE database.', Publication Date='May, 2024'
# Processing PMID=38740730, Title='Themes, Rates, and Risk of Adverse Events of the Artificial Pancreas in the United States Using MAUDE.', Publication Date='May, 2024'
# Processing PMID=38694934, Title='Adverse Events in Total Artificial Heart for End-Stage Heart Failure: Insight From the Food and Drug Administration Manufacturer and User Facility Device Experience (MAUDE).', Publication Date='May, 2024'
# Processing PMID=38658678, Title='Intraocular Inflammation with faricimab: insights from Manufacturer and User Facility Device Experience (MAUDE) database.', Publication Date='Apr, 2024'
# No abstract found for PMID 38658678 and Title 'Intraocular Inflammation with faricimab: insights from Manufacturer and User Facility Device Experience (MAUDE) database.'.
# Processing PMID=38635526, Title='Major Clinical Adverse Events of Breast Implant in the Manufacturer and User Facility Device Experience Database.', Publication Date='Apr, 2024'
# Processed 30 articles. Data saved.
# Processing PMID=38602895, Title='Infections Associated with Medtronic Duet External Ventricular Drains - Rhode Island Hospital, Providence, Rhode Island, January 2023-January 2024.', Publication Date='Apr, 2024'
# Processing PMID=38587020, Title='Otolaryngologists and the MAUDE Database: Hammers Looking for a Nail.', Publication Date='Apr, 2024'
# No abstract found for PMID 38587020 and Title 'Otolaryngologists and the MAUDE Database: Hammers Looking for a Nail.'.
# Processing PMID=38580887, Title='Adverse Events and Device Failures Associated with Pancreatic Stents: A Comprehensive Analysis Using the FDA's MAUDE Database.', Publication Date='Apr, 2024'
# Processing PMID=38574515, Title='Adverse events associated with Vibrant Soundbridge: A MAUDE study.', Publication Date='Apr, 2024'
# Processing PMID=38552339, Title='Adverse events associated with anastomotic coupling devices in microvascular reconstruction.', Publication Date='Mar, 2024'
# Processing PMID=38548124, Title='Catheter-related and clinical complications associated with contact force-sensing irrigated ablation catheter.', Publication Date='Mar, 2024'
# No abstract found for PMID 38548124 and Title 'Catheter-related and clinical complications associated with contact force-sensing irrigated ablation catheter.'.
# Processing PMID=38520298, Title='Are adverse events during surgery for benign prostatic hyperplasia device related? A review of the MAUDE database.', Publication Date='Mar, 2024'
# Processing PMID=38513755, Title='Adverse Events Associated with Mechanical Thrombectomy Devices in Peripheral Interventions: Review of the Manufacturer and User Facility Device Experience (MAUDE) Database.', Publication Date='Mar, 2024'
# No abstract found for PMID 38513755 and Title 'Adverse Events Associated with Mechanical Thrombectomy Devices in Peripheral Interventions: Review of the Manufacturer and User Facility Device Experience (MAUDE) Database.'.
# Processing PMID=38479218, Title='Adverse events associated with device assisted hyoid and tongue base suspension for obstructive sleep apnea.', Publication Date='Mar, 2024'
# Processing PMID=38470959, Title='Assessing the Reproducibility of Research Based on the Food and Drug Administration Manufacturer and User Facility Device Experience Data.', Publication Date='Mar, 2024'
# Processed 40 articles. Data saved.
# Processing PMID=38468214, Title='The Hairy Truth of At-Home Hair Removal: Retrospective Analysis of Over-the-Counter Light-Based Hair Removal and Hair Growth Devices in the MAUDE Database.', Publication Date='Mar, 2024'
# No abstract found for PMID 38468214 and Title 'The Hairy Truth of At-Home Hair Removal: Retrospective Analysis of Over-the-Counter Light-Based Hair Removal and Hair Growth Devices in the MAUDE Database.'.
# Processing PMID=38467899, Title='Patient Complications and Device Issues Associated With FDA-Approved Intragastric Balloons Available in the USA: A Maude Database Study.', Publication Date='Mar, 2024'
# No abstract found for PMID 38467899 and Title 'Patient Complications and Device Issues Associated With FDA-Approved Intragastric Balloons Available in the USA: A Maude Database Study.'.
# Processing PMID=38467236, Title='Medical device report analyses from MAUDE: Device and patient outcomes, adverse events, and sex-based differential effects.', Publication Date='Mar, 2024'
# Processing PMID=38458325, Title='Major Complications and Adverse Events Related to Use of SpaceOAR Hydrogel for Prostate Cancer Radiotherapy.', Publication Date='Mar, 2024'
# Processing PMID=38417263, Title='Soft tissue injury events associated with neural integrity monitoring endotracheal tubes: A MAUDE database analysis.', Publication Date='Feb, 2024'
# Processing PMID=38327259, Title='Considerations for Use of the MAUDE Database in Otolaryngology-Head & Neck Surgery Research.', Publication Date='Feb, 2024'
# Processing PMID=38316225, Title='Adverse events of the single-operator cholangioscopy system: a Manufacturer and User Facility Device Experience database analysis.', Publication Date='Feb, 2024'
# Processing PMID=38313458, Title='Adverse events associated with the gold probe and the injection gold probe devices used for endoscopic hemostasis: A MAUDE database analysis.', Publication Date='Feb, 2024'
# Processing PMID=38312201, Title='Leadless pacemaker tine damage and fracture: novel complications of a novel device fixation mechanism.', Publication Date='Feb, 2024'
# Processing PMID=38269880, Title='Automating the Identification of Safety Events Involving Machine Learning-Enabled Medical Devices.', Publication Date='Jan, 2024'
# Processed 50 articles. Data saved.
# Processing PMID=38250172, Title='Editorial: Female urogenital devices used during their lifetime-managing menstruation including pelvic health.', Publication Date='Jan, 2024'
# No abstract found for PMID 38250172 and Title 'Editorial: Female urogenital devices used during their lifetime-managing menstruation including pelvic health.'.
# Processing PMID=38224297, Title='Modes of failure of guide catheter extensions: Insights from the MAUDE database.', Publication Date='Jan, 2024'
# Processing PMID=38224197, Title='Development of an Improved LASER-Resistant Endotracheal Tube.', Publication Date='Jan, 2024'
# Processing PMID=38179023, Title='Adverse events related to accessory devices used during ureteroscopy: Findings from a 10-year analysis of the Manufacturer and User Facility Device Experience (MAUDE) database.', Publication Date='Jan, 2024'
# Processing PMID=38063212, Title='Comparing adverse events associated with LigaSure and Harmonic devices in head and neck surgery.', Publication Date='Dec, 2023'
# Processing PMID=38130257, Title='Complications of eustachian tube balloon dilation: Manufacturer and User Facility Device Experience (MAUDE) database analysis and literature review.', Publication Date='Dec, 2023'
# Processing PMID=38110358, Title='Real-World Experience With the Angio-Seal Closure Device: Insights From Manufacturer and User Facility Device Experience Database.', Publication Date='Dec, 2023'
# Processing PMID=38108883, Title='The burning truth about light therapy: a retrospective analysis of the MAUDE database on UV phototherapy and photodynamic therapy complications 2013-2023.', Publication Date='Dec, 2023'
# Processing PMID=38138158, Title='LARIAT or AtriClip: Complications Profile and Comparison in Patients with Atrial Fibrillations Based on Manufacturer and User Facility Device Experience Database.', Publication Date='Dec, 2023'
# Abstract found by title search for Title: 'LARIAT or AtriClip: Complications Profile and Comparison in Patients with Atrial Fibrillations Based on Manufacturer and User Facility Device Experience Database.' using PMID: 39227617
# Processing PMID=37983110, Title='Adverse events with intravascular lithotripsy after coronary use: A report from the FDA MAUDE database.', Publication Date='Nov, 2023'
# Processed 60 articles. Data saved.
# Processing PMID=37973071, Title='Polyether Ether Ketone (PEEK) Implants and the Manufacturer and User Facility Device Experience (MAUDE) Database: An Updated Review of Adverse Events and Complications.', Publication Date='Nov, 2023'
# Processing PMID=37969167, Title='Device malfunctions with use of EUS-guided fine-needle biopsy devices: Analysis of the MAUDE database.', Publication Date='Nov, 2023'
# Processing PMID=37956776, Title='Failure to defibrillate or cardiovert due to premature truncation of biphasic shocks from implantable defibrillators.', Publication Date='Nov, 2023'
# Processing PMID=37954315, Title='Evidence-based clinical engineering: Health information technology adverse events identification and classification with natural language processing.', Publication Date='Nov, 2023'
# Error fetching full-text link for PMID 37954315: Response ended prematurely
# Processing PMID=37944306, Title='Characterizing complications associated with skull clamps: A review of the manufacturer and user facility device experience database.', Publication Date='Nov, 2023'
# Processing PMID=37890052, Title='Pediatric Airway Balloon Dilation: Urge for Safety Redesign.', Publication Date='Oct, 2023'
# Processing PMID=37868127, Title='Complications Associated with Microdebriders in Otolaryngology Procedures from 2011 to 2021: A MAUDE Study.', Publication Date='Oct, 2023'
# Processing PMID=37862881, Title='Nasal Epistaxis Balloons: A Comprehensive MAUDE Database Analysis.', Publication Date='Oct, 2023'
# Processing PMID=37799789, Title='Adverse events in cryoballoon ablation for pulmonary vein isolation: Insight from the Food and Drug Administration Manufacturer and User Facility Device Experience.', Publication Date='Oct, 2023'
# Processing PMID=37774851, Title='Real-World Complications of the SpaceOAR Hydrogel Spacer: A Review of the Manufacturer and User Facility Device Experience Database.', Publication Date='Sep, 2023'
# Processed 70 articles. Data saved.
# Processing PMID=37750495, Title='Insights From the FDA's MAUDE Database Regarding the Real-World Safety of Jetstream Atherectomy for Peripheral Arterial Disease.', Publication Date='Sep, 2023'
# Processing PMID=37746939, Title='Complications of Novel Radiofrequency Device Use in Rhinology: A MAUDE Analysis.', Publication Date='Sep, 2023'
# Processing PMID=37732709, Title='Respiratory Sensing Lead Malfunction in Upper Airway Stimulation: A Single Institution Report.', Publication Date='Sep, 2023'
# Processing PMID=37729644, Title='Adverse Event Reporting of Commonly Used Gender-Specific Implantable Medical Devices in the United States.', Publication Date='Sep, 2023'
# Processing PMID=37727161, Title='Investigating the Complications and Causes of Failure of the AngioVac System: A Post-Marketing Surveillance From the MAUDE Database.', Publication Date='Sep, 2023'
# Processing PMID=37679961, Title='Adverse events associated with amplatzer left atrial appendage occlusion delivery system: A Food and Drug Administration MAUDE database study.', Publication Date='Sep, 2023'
# Processing PMID=37668414, Title='Analysis of Reported Adverse Events Related to Hemospray an FDA MAUDE Database Study.', Publication Date='Sep, 2023'
# No abstract found for PMID 37668414 and Title 'Analysis of Reported Adverse Events Related to Hemospray an FDA MAUDE Database Study.'.
# Processing PMID=37664247, Title='The Prevalence of Cardiovascular Complications and Causes of AngioJet Failure: A Post-Marketing Surveillance Study Based on the MAUDE (Manufacturer and User Facility Device Experience) Database.', Publication Date='Sep, 2023'
# Processing PMID=37635415, Title='Eustachian Tube Balloon Dilation: A Comprehensive Analysis of Adverse Events.', Publication Date='Aug, 2023'
# Processing PMID=37622490, Title='Adverse Events Associated With Tracheostomy: A MAUDE Database Analysis.', Publication Date='Aug, 2023'
# Processed 80 articles. Data saved.
# Processing PMID=37616552, Title='Epidemiology of Breast Implant-Associated Anaplastic Large Cell Lymphoma in the United States: A Systematic Review.', Publication Date='Aug, 2023'
# Processing PMID=37594003, Title='"Weekend Facelifts" Gone Wrong: Retrospective Analysis of the MAUDE Database on Thread-Lifting Complications From 2003-2023.', Publication Date='Aug, 2023'
# No abstract found for PMID 37594003 and Title '"Weekend Facelifts" Gone Wrong: Retrospective Analysis of the MAUDE Database on Thread-Lifting Complications From 2003-2023.'.
# Processing PMID=37565059, Title='Adverse Events and Subsequent Management Associated With Eustachian Tube Balloon Dilation.', Publication Date='Aug, 2023'
# Processing PMID=37558289, Title='Post-Shock Asystole in Patients Dying Out of Hospital While Wearing a Cardioverter Defibrillator.', Publication Date='Aug, 2023'
# Processing PMID=37553285, Title='Carotid artery dissections from transcarotid artery revascularization as reported by the Food and Drug Administration.', Publication Date='Aug, 2023'
# Processing PMID=37544803, Title='Editorial: Adverse events from intra-aortic balloon counterpulsation therapy: Insights from the MAUDE database.', Publication Date='Aug, 2023'
# No abstract found for PMID 37544803 and Title 'Editorial: Adverse events from intra-aortic balloon counterpulsation therapy: Insights from the MAUDE database.'.
# Processing PMID=37519343, Title='Safety reporting of Essure medical device: a qualitative and quantitative assessment on the FDA manufacturer and user facility device experience database in 2018.', Publication Date='Jul, 2023'
# Processing PMID=37504239, Title='Adverse Events Related to Direct-To-Consumer Sequential Aligners-A Study of the MAUDE Database.', Publication Date='Jul, 2023'
# Processing PMID=37497812, Title='Understanding a decade of safety reporting for sacral neuromodulation in the Food and Drug Administration Manufacturer and User Facility Device Experience database.', Publication Date='Jul, 2023'
# Processing PMID=37485105, Title='Coronary Intra-orbital Atherectomy Complications and Procedural Failure: Insight From the Manufacturer and User Facility Device Experience (MAUDE) Database.', Publication Date='Jul, 2023'
# Processed 90 articles. Data saved.
# Processing PMID=37478536, Title='Airway fires in otolaryngologic surgery: A database review.', Publication Date='Jul, 2023'
# Processing PMID=37387528, Title='Fat removal and risk accrual: A retrospective analysis of the MAUDE database on liposuction complications from 2013 to 2023.', Publication Date='Jun, 2023'
# No abstract found for PMID 37387528 and Title 'Fat removal and risk accrual: A retrospective analysis of the MAUDE database on liposuction complications from 2013 to 2023.'.
# Processing PMID=37348092, Title='Radiofrequency Ablation for Treatment of Leiomyomas: Review of the Manufacturer and User Facility Device Experience (MAUDE) Database.', Publication Date='Jun, 2023'
# Processing PMID=37343508, Title='Otologic use of porcine small intestinal submucosal graft (biodesign): A MAUDE database review.', Publication Date='Jun, 2023'
# Processing PMID=37341672, Title='Adverse Events and Complications Associated With Vagal Nerve Stimulation: An Analysis of the Manufacturer And User Facility Device Experience Database.', Publication Date='Jun, 2023'
# Processing PMID=37306231, Title='Surgical Fires Involving Alcohol-Based Preparation Solution, 1991-2020.', Publication Date='Jun, 2023'
# Processing PMID=37302952, Title='Characteristic adverse events with intra-aortic balloon pumps: An analysis of the U.S. Food and Drug Administration MAUDE database from 2016 to 2021.', Publication Date='Jun, 2023'
# Processing PMID=37295507, Title='Microwave energy devices for hyperhidrosis are associated with infections, neurologic symptoms, and burns in a retrospective analysis of the Manufacturer and User Facility Device Experience database 2013-2022.', Publication Date='Jun, 2023'
# No abstract found for PMID 37295507 and Title 'Microwave energy devices for hyperhidrosis are associated with infections, neurologic symptoms, and burns in a retrospective analysis of the Manufacturer and User Facility Device Experience database 2013-2022.'.
# Processing PMID=37292024, Title='Complications and device failures associated with urolift: Findings from the MAUDE database.', Publication Date='Jun, 2023'
# Processing PMID=37278214, Title='Complications of cochlear implants: a MAUDE database study.', Publication Date='Jun, 2023'
# Processed 100 articles. Data saved.
# Processing PMID=37267458, Title='Analysis of Reported Adverse Events Related to Hemospray: An FDA MAUDE Database Study.', Publication Date='Jun, 2023'
# Processing PMID=37264590, Title='Adverse Event Causes From 2022 for Four Continuous Glucose Monitors.', Publication Date='Jun, 2023'
# Processing PMID=37254239, Title='The Use and Utility of Food and Drug Administration Adverse Event Data from the Manufacturer and User Facility Device Experience Database in Otology: A Systematic Review.', Publication Date='May, 2023'
# Processing PMID=37225596, Title='EDITORIAL COMMENT Re: Device Failure and Adverse Events Related to Single-use and Reusable Flexible Ureteroscopes: Findings and New Insights From an 11-Year Analysis of the Manufacturer and User Facility Device Experience Database. Urology. 2023 Jul;177:41-47.', Publication Date='May, 2023'
# No abstract found for PMID 37225596 and Title 'EDITORIAL COMMENT Re: Device Failure and Adverse Events Related to Single-use and Reusable Flexible Ureteroscopes: Findings and New Insights From an 11-Year Analysis of the Manufacturer and User Facility Device Experience Database. Urology. 2023 Jul;177:41-47.'.
# Processing PMID=37222779, Title='Complications associated with minimally invasive surgical therapies (MIST) for surgical management of benign prostatic hyperplasia: a Manufacturer and User Facility Device Experience (MAUDE) database review.', Publication Date='May, 2023'
# Processing PMID=37209414, Title='Adverse events associated with AveirTM VR leadless pacemaker: A Food and Drug Administration MAUDE database study.', Publication Date='May, 2023'
# Processing PMID=37178539, Title='Comparing nationally reported adverse events associated with coblation vs. PlasmaBlade for tonsillectomy.', Publication Date='May, 2023'
# Processing PMID=37084162, Title='Patient adverse events and technical failures with the bravo capsule pH system: insights from the MAUDE database.', Publication Date='Apr, 2023'
# Processing PMID=37071804, Title='More than algorithms: an analysis of safety events involving ML-enabled medical devices reported to the FDA.', Publication Date='Apr, 2023'
# Processing PMID=37044309, Title='Device Failure and Adverse Events Related to Single-use and Reusable Flexible Ureteroscopes: Findings and New Insights From an 11-Year Analysis of the Manufacturer and User Facility Device Experience Database.', Publication Date='Apr, 2023'
# Processed 110 articles. Data saved.
# Processing PMID=37023704, Title='Typology, Severity, and Outcomes of Adverse Events Related to Angiographic Equipment-A Ten-Year Analysis of the FDA MAUDE Database.', Publication Date='Apr, 2023'
# No abstract found for PMID 37023704 and Title 'Typology, Severity, and Outcomes of Adverse Events Related to Angiographic Equipment-A Ten-Year Analysis of the FDA MAUDE Database.'.
# Processing PMID=37006740, Title='Complications associated with energy-based devices during thyroidectomy from 2010-2020.', Publication Date='Apr, 2023'
# Processing PMID=36976929, Title='Analysis of Reported Adverse Events With Colonic Stents: An FDA MAUDE Database Study.', Publication Date='Mar, 2023'
# No abstract found for PMID 36976929 and Title 'Analysis of Reported Adverse Events With Colonic Stents: An FDA MAUDE Database Study.'.
# Processing PMID=36972147, Title='Are all Cages Created Equal? Analysis of Cervical Cage Malfunctions Using FDA MAUDE Database.', Publication Date='Mar, 2023'
# Processing PMID=36939542, Title='Adverse Events Associated With Bioabsorbable Nasal Implants: A MAUDE Database Analysis.', Publication Date='Mar, 2023'
# Processing PMID=36914509, Title='Invited commentary: Mortality associated with the use of stapler devices and clip appliers: Analysis of the Food and Drug Administration Manufacturer and User Facility Device Experience database.', Publication Date='Mar, 2023'
# No abstract found for PMID 36914509 and Title 'Invited commentary: Mortality associated with the use of stapler devices and clip appliers: Analysis of the Food and Drug Administration Manufacturer and User Facility Device Experience database.'.
# Processing PMID=36883997, Title='Assessment of adverse events for a home-use intense pulsed light hair removal device using postmarketing surveillance.', Publication Date='Mar, 2023'
# Processing PMID=36871655, Title='Metal-Free Cortico-Pedicular Device for Supplemental Fixation in Lumbar Interbody Fusion.', Publication Date='Mar, 2023'
# Processing PMID=36854913, Title='Intrapulmonary Feeding Tube Placements While Using an Electromagnetic Placement Device: A Review (2019-2021).', Publication Date='Mar, 2023'
# Processing PMID=36849311, Title='Complications and Failure of the Terumo Radial to Peripheral (R2P) Slender Destination Sheath: Insight from the MAUDE Database.', Publication Date='Feb, 2023'
# No abstract found for PMID 36849311 and Title 'Complications and Failure of the Terumo Radial to Peripheral (R2P) Slender Destination Sheath: Insight from the MAUDE Database.'.
# Processed 120 articles. Data saved.
# Processing PMID=36810809, Title='Analysis of Reported Adverse Events Associated with Over-the-Scope Endoscopic Suturing System: an FDA MAUDE Database Study.', Publication Date='Feb, 2023'
# Processing PMID=36789489, Title='Analysis of reported adverse events of pipeline stents for intracranial aneurysms using the FDA MAUDE database.', Publication Date='Feb, 2023'
# Processing PMID=36788718, Title='Facial Dermal Filler Injection and Vaccination: A 12-Year Review of Adverse Event Reporting and Literature Review.', Publication Date='Feb, 2023'
# Processing PMID=36728443, Title='Adverse Events of Endoscopic Clip Placement: A MAUDE Database Analysis.', Publication Date='Feb, 2023'
# Processing PMID=36727830, Title='An Analysis of a Decade of Lumbar Interbody Cage Failures in the United States: A MAUDE Database Study.', Publication Date='Feb, 2023'
# Processing PMID=36724310, Title='Insulin Pump-Associated Adverse Events: A Qualitative Descriptive Study of Clinical Consequences and Potential Root Causes.', Publication Date='Feb, 2023'
# Abstract found by title search for Title: 'Insulin Pump-Associated Adverse Events: A Qualitative Descriptive Study of Clinical Consequences and Potential Root Causes.' using PMID: 37905930
# Processing PMID=36669984, Title='MitraClip Arm Lock Failure: A Review of Device Reports to the FDA MAUDE Database.', Publication Date='Jan, 2023'
# No abstract found for PMID 36669984 and Title 'MitraClip Arm Lock Failure: A Review of Device Reports to the FDA MAUDE Database.'.
# Processing PMID=36528205, Title='Major Complications and Failure Modes of the Angiosculpt Scoring Balloon Catheter: Analysis of the MAUDE Database.', Publication Date='Dec, 2022'
# Processing PMID=36564288, Title='Mortality related to the use of stapler devices and clip appliers: Analysis of the Food and Drug Administration Manufacturer and User Facility Device Experience database.', Publication Date='Dec, 2022'
# Processing PMID=36526567, Title='Post-Approval Safety Profile of Amulet vs Watchman FLX Left Atrial Appendage Closure Devices: Analysis from the MAUDE Database (ALERT-MAUDE Study).', Publication Date='Dec, 2022'
# No abstract found for PMID 36526567 and Title 'Post-Approval Safety Profile of Amulet vs Watchman FLX Left Atrial Appendage Closure Devices: Analysis from the MAUDE Database (ALERT-MAUDE Study).'.
# Error fetching full-text link for PMID 36526567: Response ended prematurely
# Processed 130 articles. Data saved.
# Processing PMID=36495577, Title='Post-cystoscopy infections and device malfunctions in reprocessed flexible cystoscopes in a national database.', Publication Date='Dec, 2022'
# Error fetching full-text link for PMID 36495577: 500 Server Error: Internal Server Error for url: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/elink.fcgi?dbfrom=pubmed&db=pmc&id=36495577&retmode=xml&email=lhua0420%40gmail.com&api_key=f0b970f706ba8babb0bb582a384964d8b508
# Processing PMID=36461676, Title='Analysis of Polyethylene-Related Revisions After Total Ankle Replacements Reported in US Food and Drug Administration Medical Device Adverse Event Database.', Publication Date='Dec, 2022'
# Processing PMID=36416861, Title='Laryngology Outcomes Following Implantable Vagus Nerve Stimulation.', Publication Date='Nov, 2022'
# Processing PMID=36372572, Title='Surgical Fire in the United States: 2000-2020.', Publication Date='Nov, 2022'
# Processing PMID=36226833, Title='Safe design of surgical robots - a systematic approach to comprehensive hazard identification.', Publication Date='Oct, 2022'
# Processing PMID=36220381, Title='Patient-related adverse events and device failures associated with commercially available enteral or duodenal self-expanding metal stents: an analysis of the MAUDE database.', Publication Date='Oct, 2022'
# Processing PMID=36209962, Title='Association Between Device Type and Type IIIb Endoleaks Following Thoracic Endovascular Aortic Repair.', Publication Date='Oct, 2022'
# Processing PMID=36198829, Title='Automated insulin delivery: benefits, challenges, and recommendations. A Consensus Report of the Joint Diabetes Technology Working Group of the European Association for the Study of Diabetes and the American Diabetes Association.', Publication Date='Oct, 2022'
# Processing PMID=36054047, Title='Adverse Events of Non-Invasive Body Contouring: Analysis of the Food and Drug Administration Manufacturer and User Facility Device Experience Database.', Publication Date='Sep, 2022'
# Processing PMID=36103654, Title='The Patient Narrative for Breast Implant Illness: A 10-Year Review of the U.S. Food and Drug Administration's MAUDE Database.', Publication Date='Sep, 2022'
# Processed 140 articles. Data saved.
# Processing PMID=36074993, Title='Reported Events Associated With Spine Robots: An Analysis of the Food and Drug Administration's Manufacturer and User Facility Device Experience Database.', Publication Date='Sep, 2022'
# Processing PMID=36071989, Title='Exploring Adverse Events and Utilization of Topical Hemostatic Agents in Surgery.', Publication Date='Sep, 2022'
# Processing PMID=36055459, Title='A Comparison of Patient and Device Issues Reported for Recalled Venous Stent Systems.', Publication Date='Sep, 2022'
# Processing PMID=36128133, Title='Deep brain stimulation for refractory obsessive-compulsive disorder: A review and analysis of the FDA MAUDE database.', Publication Date='Sep, 2022'
# Processing PMID=35993683, Title='Breast Implant-Related Adverse Events During Mammography: An Assessment of the Food and Drug Administration Manufacturer and User Facility Device Experience Database.', Publication Date='Aug, 2022'
# Processing PMID=35991750, Title='Complications associated with PEAK PlasmaBlade from 2010 to 2020 from MAUDE.', Publication Date='Aug, 2022'
# Processing PMID=35935150, Title='Percutaneous Ventricular Assist Device Fracture in the Right Ventricle and its Retrieval.', Publication Date='Aug, 2022'
# Processing PMID=35931414, Title='Adverse events associated with the bridge occlusion balloon for lead extraction: A MAUDE database study.', Publication Date='Aug, 2022'
# No abstract found for PMID 35931414 and Title 'Adverse events associated with the bridge occlusion balloon for lead extraction: A MAUDE database study.'.
# Processing PMID=35916105, Title='FDA MAUDE database reported adverse events on noninvasive body contouring, cellulite treatment, and muscle stimulation from 2015 to 2021.', Publication Date='Aug, 2022'
# Processing PMID=35850967, Title='Excimer Laser-Induced Adverse Coronary Events: Discerning the Merits and Shortcomings of the MAUDE Database Report.', Publication Date='Jul, 2022'
# No abstract found for PMID 35850967 and Title 'Excimer Laser-Induced Adverse Coronary Events: Discerning the Merits and Shortcomings of the MAUDE Database Report.'.
# Processed 150 articles. Data saved.
# Processing PMID=35833501, Title='Image-Guided Surgical Device Failures in Functional Endoscopic Sinus Surgery: A MAUDE Analysis.', Publication Date='Jul, 2022'
# Processing PMID=35809006, Title='Topical Wound Therapy Products With Ionic Silver: A Technologic Analysis.', Publication Date='Jul, 2022'
# Processing PMID=35803778, Title='Postapproval Safety Profiles of Different Implantable Cardiac Monitor Devices (from a Food and Drug Administration MAUDE Database Study).', Publication Date='Jul, 2022'
# No abstract found for PMID 35803778 and Title 'Postapproval Safety Profiles of Different Implantable Cardiac Monitor Devices (from a Food and Drug Administration MAUDE Database Study).'.
# Processing PMID=35798594, Title='Adverse Events Associated With the C304 His Sheath Used for Conduction System Pacing: A MAUDE Database Analysis.', Publication Date='Jul, 2022'
# No abstract found for PMID 35798594 and Title 'Adverse Events Associated With the C304 His Sheath Used for Conduction System Pacing: A MAUDE Database Analysis.'.
# Processing PMID=35784622, Title='Clinical adverse events and device failures for the Barrx™ radiofrequency ablation catheter system: a MAUDE database analysis.', Publication Date='Jul, 2022'
# Processing PMID=35781070, Title='Adverse Events Associated with New Nitinol Venous-Labeled Stents: A Review of the FDA MAUDE Database.', Publication Date='Jul, 2022'
# No abstract found for PMID 35781070 and Title 'Adverse Events Associated with New Nitinol Venous-Labeled Stents: A Review of the FDA MAUDE Database.'.
# Processing PMID=35778250, Title='Complications With Noninvasive Fat and Cellulite Reduction Devices: A Cross-sectional Analysis of the US Food and Drug Administration Manufacturer and User Facility Device Experience Database.', Publication Date='Jul, 2022'
# Processing PMID=35771964, Title='Development of an Inventory of Dental Harms: Methods and Rationale.', Publication Date='Jul, 2022'
# Processing PMID=35698284, Title='Complications of Endobronchial Valve Placement for Bronchoscopic Lung Volume Reduction: Insights From the Food and Drug Administration Manufacturer and User Facility Device Experience (MAUDE).', Publication Date='Jun, 2022'
# Processing PMID=35727630, Title='Adverse Events Associated With Image-Guided Sinus Navigation in Endoscopic Sinus Surgery: A MAUDE Database Analysis.', Publication Date='Jun, 2022'
# Processed 160 articles. Data saved.
# Processing PMID=35718067, Title='Comparison of technical failures and patient-related adverse events associated with 3 widely used mechanical lithotripters for ERCP: insights from the U.S. Food and Drug Administration Manufacturer and User Facility Device Experience database.', Publication Date='Jun, 2022'
# Processing PMID=35734685, Title='Turnpike Catheter failure, causes and mechanisms: Insights from the MAUDE database.', Publication Date='Jun, 2022'
# Processing PMID=35653558, Title='Characterizing Ocular Adverse Events After Facial Dermal Filler Injection-Reviewing the MAUDE Database.', Publication Date='Jun, 2022'
# Error fetching abstract for PMID 35653558: HTTPSConnectionPool(host='eutils.ncbi.nlm.nih.gov', port=443): Max retries exceeded with url: /entrez/eutils/efetch.fcgi?db=pubmed&id=35653558&rettype=abstract&retmode=xml&email=lhua0420%40gmail.com&api_key=f0b970f706ba8babb0bb582a384964d8b508 (Caused by SSLError(SSLZeroReturnError(6, 'TLS/SSL connection has been closed (EOF) (_ssl.c:1129)')))
# Abstract found by title search for Title: 'Characterizing Ocular Adverse Events After Facial Dermal Filler Injection-Reviewing the MAUDE Database.' using PMID: 35653558
# Processing PMID=35579193, Title='Adverse events of subcutaneous loop recorders: Insights from the MAUDE database.', Publication Date='May, 2022'
# Processing PMID=35536679, Title='Complications Reported to the Food and Drug Administration: A Cross-sectional Comparison of Urogynecologic Meshes.', Publication Date='May, 2022'
# Processing PMID=35523236, Title='Intra-Abdominal Pressure Measurement Devices: A Technologic Analysis.', Publication Date='May, 2022'
# Processing PMID=35490711, Title='Adverse events associated with the AtriClip device for left atrial appendage occlusion: A Food and Drug Administration MAUDE database study.', Publication Date='May, 2022'
# No abstract found for PMID 35490711 and Title 'Adverse events associated with the AtriClip device for left atrial appendage occlusion: A Food and Drug Administration MAUDE database study.'.
# Processing PMID=35470284, Title='Clinical Adverse Events and Device Failures Reported for the Captivator and Duette Endoscopic Mucosal Resection (EMR) Systems: A MAUDE Database Analysis.', Publication Date='Apr, 2022'
# Processing PMID=35421039, Title='Manufacturer and User Facility Device Experience Reporting of Events Related to Transvaginal Mesh: Understanding the Data.', Publication Date='Apr, 2022'
# Processing PMID=35379535, Title='Device-related complications during renal cryoablation: insights from the Manufacturer and User Facility Device Experience (MAUDE) database.', Publication Date='Apr, 2022'
# Processed 170 articles. Data saved.
# Processing PMID=35352830, Title='Cancer Risk Associated with Continuous Positive Airway Pressure: A National Study.', Publication Date='Mar, 2022'
# Processing PMID=35314290, Title='Adverse Events Associated With Robotic-Assisted Joint Arthroplasty: An Analysis of the US Food and Drug Administration MAUDE Database.', Publication Date='Mar, 2022'
# Processing PMID=35281706, Title='Stapler Malfunctions in Bariatric Surgery: An Analysis of the MAUDE Database.', Publication Date='Mar, 2022'
# Processing PMID=35255062, Title='Abdominal Negative Pressure Wound Therapy Devices for Management of the Open Abdomen: A Technologic Analysis.', Publication Date='Mar, 2022'
# Processing PMID=35239289, Title='Analysis of Complications in Sacroiliac Joint Fusions Using FDA 510(k) Cleared Devices.', Publication Date='Mar, 2022'
# Processing PMID=35202776, Title='Retrospective analysis of the MAUDE database on dermal filler complications from 2014-2020.', Publication Date='Feb, 2022'
# No abstract found for PMID 35202776 and Title 'Retrospective analysis of the MAUDE database on dermal filler complications from 2014-2020.'.
# Processing PMID=35210113, Title='Breaking it down: Review and management of sialendoscopy device malfunctions.', Publication Date='Feb, 2022'
# Processing PMID=35183542, Title='Analysis of reported adverse events related to single-use duodenoscopes and duodenoscopes with detachable endcaps.', Publication Date='Feb, 2022'
# Processing PMID=35140755, Title='FDA MAUDE database analysis of titanium middle ear prosthesis.', Publication Date='Feb, 2022'
# Processing PMID=35132023, Title='Adverse Events Associated With 10-kHz Dorsal Column Spinal Cord Stimulation: A 5-Year Analysis of the Manufacturer and User Facility Device Experience (MAUDE) Database.', Publication Date='Feb, 2022'
# Processed 180 articles. Data saved.
# Processing PMID=35125145, Title='Characterizing Complications of Intracranial Responsive Neurostimulation Devices for Epilepsy Through a Retrospective Analysis of the Federal MAUDE Database.', Publication Date='Feb, 2022'
# Processing PMID=35083979, Title='Adverse events associated with AXIOS stents: Insights from the manufacturer and user facility device experience database.', Publication Date='Jan, 2022'
# Processing PMID=35059533, Title='Devices for esophageal function testing.', Publication Date='Jan, 2022'
# Processing PMID=35017113, Title='Post-FDA approval "real-world" safety profile of different steerable sheaths during catheter ablation: A Food and Drug Administration MAUDE database study.', Publication Date='Jan, 2022'
# No abstract found for PMID 35017113 and Title 'Post-FDA approval "real-world" safety profile of different steerable sheaths during catheter ablation: A Food and Drug Administration MAUDE database study.'.
# Processing PMID=34953250, Title='Complications associated with Dermabond® during head and neck surgery: MAUDE and literature review.', Publication Date='Dec, 2021'
# Processing PMID=34953099, Title='Leadless pacemaker perforations: Clinical consequences and related device and user problems.', Publication Date='Dec, 2021'
# Processing PMID=34935756, Title='Postmarket Safety Surveillance of Delayed Complications for Recent FDA-Approved Hyaluronic Acid Dermal Fillers.', Publication Date='Dec, 2021'
# Processing PMID=34919294, Title='Assessing adverse event reports of hysteroscopic sterilization device removal using natural language processing.', Publication Date='Dec, 2021'
# Processing PMID=34917966, Title='A Retained Intracardiac Catheter Contributing to Worsening Heart Failure and Atrial Fibrillation: Investigation and Management.', Publication Date='Dec, 2021'
# Processing PMID=34907923, Title='Analysis of Reported Adverse Events With Colonic Stents: An FDA MAUDE Database Study.', Publication Date='Dec, 2021'
# Processed 190 articles. Data saved.
# Processing PMID=34906438, Title='Complications and Failure Modes of Polymer-Jacketed Guidewires; Insights From the MAUDE Database.', Publication Date='Dec, 2021'
# No abstract found for PMID 34906438 and Title 'Complications and Failure Modes of Polymer-Jacketed Guidewires; Insights From the MAUDE Database.'.
# Processing PMID=34889828, Title='Adverse Events Associated With Ossicular Prostheses: Utility of a Federal Database.', Publication Date='Dec, 2021'
# Processing PMID=34866049, Title='Adverse Events With Intravascular Lithotripsy After Peripheral and Off-Label Coronary Use: A Report From the FDA MAUDE Database.', Publication Date='Dec, 2021'
# Processing PMID=34862784, Title='[Risk Analysis for Bakri Postpartum Balloon in Clinic].', Publication Date='Dec, 2021'
# Abstract found by title search for Title: '[Risk Analysis for Bakri Postpartum Balloon in Clinic].' using PMID: 35291903
# Processing PMID=34750704, Title='Adverse events associated with transoral incisionless fundoplication (TIF) for chronic gastroesophageal reflux disease: a MAUDE database analysis.', Publication Date='Nov, 2021'
# Processing PMID=34784851, Title='Experience of the moray micro forceps biopsy for pancreatic cystic lesions: lessons and insights from the MAUDE database.', Publication Date='Nov, 2021'
# No abstract found for PMID 34784851 and Title 'Experience of the moray micro forceps biopsy for pancreatic cystic lesions: lessons and insights from the MAUDE database.'.
# Processing PMID=34750929, Title='Adverse events related to AtriCure EPi-Sense Coagulation Device-Analysis of the FDA MAUDE database.', Publication Date='Nov, 2021'
# Processing PMID=34842892, Title='Renewing the Call for Reforms to Medical Device Safety-The Case of Penumbra.', Publication Date='Nov, 2021'
# Processing PMID=34706845, Title='Complications of Penumbra Indigo Aspiration Device in Pulmonary Embolism: Insights From MAUDE Database.', Publication Date='Oct, 2021'
# Processing PMID=34699910, Title='Adverse events with HeartMate-3 Left ventricular assist device: Results from the Manufacturer and User Facility Device Experience (MAUDE) database.', Publication Date='Oct, 2021'
# Processed 200 articles. Data saved.
# Processing PMID=34678524, Title='Postapproval safety profile of Watchman FLX left atrial appendage occlusion device: Analysis from the MAUDE database.', Publication Date='Oct, 2021'
# No abstract found for PMID 34678524 and Title 'Postapproval safety profile of Watchman FLX left atrial appendage occlusion device: Analysis from the MAUDE database.'.
# Processing PMID=34651509, Title='Analysis of "Multicenter Evaluation Study Comparing a New Factory-Calibrated Real-Time Continuous Glucose Monitoring System to Existing Flash Glucose Monitoring System".', Publication Date='Oct, 2021'
# Processing PMID=34632803, Title='Manufacturers Need to Assess Rather Than Ignore User Complaints About Their Diabetes Devices.', Publication Date='Oct, 2021'
# No abstract found for PMID 34632803 and Title 'Manufacturers Need to Assess Rather Than Ignore User Complaints About Their Diabetes Devices.'.
# Processing PMID=34610901, Title='Adverse Events Following Transcatheter Edge-to-Edge Repair (TEER) Using MitraClip: Lessons Learned From the Manufacturer and User Facility Device Experience (MAUDE) Registry.', Publication Date='Oct, 2021'
# Error fetching full-text link for PMID 34610901: Response ended prematurely
# Processing PMID=34600853, Title='Procedural Complications Involving the Laser Balloon: Insight From the FDA's MAUDE Database.', Publication Date='Oct, 2021'
# No abstract found for PMID 34600853 and Title 'Procedural Complications Involving the Laser Balloon: Insight From the FDA's MAUDE Database.'.
# Processing PMID=34480524, Title='Contemporary post-marketing adverse events and modes of failure related to VASCADE Vascular Closure System: The utility of the MAUDE database.', Publication Date='Sep, 2021'
# Error fetching full-text link for PMID 34480524: 500 Server Error: Internal Server Error for url: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/elink.fcgi?dbfrom=pubmed&db=pmc&id=34480524&retmode=xml&email=lhua0420%40gmail.com&api_key=f0b970f706ba8babb0bb582a384964d8b508
# Processing PMID=34513401, Title='Characterizing Adverse Events of Cranioplasty Implants After Craniectomy: A Retrospective Review of the Federal Manufacturer and User Facility Device Experience Database.', Publication Date='Sep, 2021'
# Processing PMID=34510115, Title='A Review of Reported Adverse Events in MRI-Safe and MRI-Conditional Cochlear Implants.', Publication Date='Sep, 2021'
# Processing PMID=34508038, Title='Ultrasonic Device Complications in Endodontics: An Analysis of Adverse Events From the Food and Drug Administration Manufacturer and User Facility Device Experience.', Publication Date='Sep, 2021'
# Processing PMID=34547903, Title='Complications Associated With Nasopharyngeal COVID-19 Testing: An Analysis of the MAUDE Database and Literature Review.', Publication Date='Sep, 2021'
# Processed 210 articles. Data saved.
# Processing PMID=34478867, Title='A cross-sectional analysis of 284 complications for lumbar disc replacements from medical device reports maintained by the United States Food and Drug Administration.', Publication Date='Sep, 2021'
# Processing PMID=34464761, Title='Malfunction Events in the US FDA MAUDE Database: How Does Robotic Gynecologic Surgery Compare with Other Specialties?', Publication Date='Sep, 2021'
# Processing PMID=34422501, Title='Correction: Characterizing Complications of Deep Brain Stimulation Devices for the Treatment of Parkinsonian Symptoms Without Tremor: A Federal MAUDE Database Analysis.', Publication Date='Aug, 2021'
# ...
# Processing PMID=22195199, Title='Application of a temporal reasoning framework tool in analysis of medical device adverse events.', Publication Date='Dec, 2011'
# Processing PMID=22095760, Title='Disproportionality analysis for signal detection of implantable cardioverter-defibrillator-related adverse events in the Food and Drug Administration Medical Device Reporting System.', Publication Date='Nov, 2011'
# Processing PMID=22044556, Title='Global robotic experience and the type of surgical system impact the types of robotic malfunctions and their clinical consequences: an FDA MAUDE review.', Publication Date='Nov, 2011'
# Processing PMID=21967534, Title='Incidence and avoidance of neurologic complications with paddle type spinal cord stimulation leads.', Publication Date='Oct, 2011'
# Processing PMID=22024114, Title='Systematic review of the use of retrievable inferior vena cava filters.', Publication Date='Oct, 2011'
# Processing PMID=21947552, Title='Entrapment of the StarClose Vascular Closure System after attempted common femoral artery deployment.', Publication Date='Sep, 2011'
# Processing PMID=21944871, Title='Cardiac tamponade as a life-threatening complication in hernia repair.', Publication Date='Sep, 2011'
# Processing PMID=21903979, Title='Using FDA reports to inform a classification for health information technology safety problems.', Publication Date='Sep, 2011'
# Processed 480 articles. Data saved.
# Processing PMID=21872969, Title='Analysis of automated external defibrillator device failures reported to the Food and Drug Administration.', Publication Date='Aug, 2011'
# Processing PMID=21777837, Title='Adverse events due to suspected nickel hypersensitivity in patients with essure micro-inserts.', Publication Date='Jul, 2011'
# Processing PMID=21762904, Title='Enteral stents.', Publication Date='Jul, 2011'
# Processing PMID=21704803, Title='GI endoscopes.', Publication Date='Jun, 2011'
# Processing PMID=21527468, Title='Incomplete deployment of the Vena Tech LP filter--case series and concerns.', Publication Date='Apr, 2011'
# Processing PMID=21303646, Title='Analysis of the performance of the CONTOUR® TS Blood Glucose Monitoring System: when regulatory performance criteria are met, should we have confidence to use a medical device with all patients?', Publication Date='Feb, 2011'
# Processing PMID=21282375, Title='Relationship between drain volume/fill volume ratio and clinical outcomes associated with overfill complaints in peritoneal dialysis patients.', Publication Date='Feb, 2011'
# Processing PMID=21237458, Title='Computer-assisted personalized sedation.', Publication Date='Jan, 2011'
# Processing PMID=21074791, Title='Complications of stone baskets: 14-year review of the manufacturer and user facility device experience database.', Publication Date='Nov, 2010'
# Processing PMID=20976748, Title='Sterile radial artery granuloma after transradial procedures: a unique and avoidable complication.', Publication Date='Oct, 2010'
# Processed 490 articles. Data saved.
# Processing PMID=20883844, Title='Endoscopic tattooing.', Publication Date='Oct, 2010'
# Processing PMID=20883843, Title='Automated endoscope reprocessors.', Publication Date='Oct, 2010'
# Processing PMID=20806458, Title='Stent fracture in the coronary and peripheral arteries.', Publication Date='Sep, 2010'
# Processing PMID=20513724, Title='A response to "Major complications associated with xenograft biologic mesh implantation in abdominal wall reconstruction" (Harth KC, Rosen MJ. Surg Innov. 2009;16:324-329) and discussion of the MAUDE (manufacturer and user facility device experience) database, FDA regulation of biologic implants, and evidence-based medicine.', Publication Date='Jun, 2010'
# No abstract found for PMID 20513724 and Title 'A response to "Major complications associated with xenograft biologic mesh implantation in abdominal wall reconstruction" (Harth KC, Rosen MJ. Surg Innov. 2009;16:324-329) and discussion of the MAUDE (manufacturer and user facility device experience) database, FDA regulation of biologic implants, and evidence-based medicine.'.
# Processing PMID=20537638, Title='Minimizing occupational hazards in endoscopy: personal protective equipment, radiation safety, and ergonomics.', Publication Date='Jun, 2010'
# Processing PMID=20541746, Title='Enteral nutrition access devices.', Publication Date='Jun, 2010'
# Processing PMID=20504796, Title='Xenograft biologic mesh implantation in abdominal wall reconstruction and the FDA MAUDE database.', Publication Date='May, 2010'
# No abstract found for PMID 20504796 and Title 'Xenograft biologic mesh implantation in abdominal wall reconstruction and the FDA MAUDE database.'.
# Processing PMID=20381044, Title='Interventional EUS.', Publication Date='Apr, 2010'
# Processing PMID=20421100, Title='The role of the U.S. Food and Drug Administration in device evaluation and monitoring.', Publication Date='Apr, 2010'
# Processing PMID=20351227, Title='Review of adverse events associated with false glucose readings measured by GDH-PQQ-based glucose test strips in the presence of interfering sugars.', Publication Date='Mar, 2010'
# Processed 500 articles. Data saved.
# Processing PMID=20347546, Title='Clinical relevance and treatment of carotid stent fractures.', Publication Date='Mar, 2010'
# Processing PMID=19946113, Title='Deaths and cardiovascular injuries due to device-assisted implantable cardioverter-defibrillator and pacemaker lead extraction.', Publication Date='Dec, 2009'
# Processing PMID=19787394, Title='ArteFill permanent injectable for soft tissue augmentation: I. Mechanism of action and injection techniques.', Publication Date='Sep, 2009'
# Processing PMID=19614901, Title='Indoor tanning injuries: an evaluation of FDA adverse event reporting data.', Publication Date='Jul, 2009'
# Processing PMID=19595398, Title='Drug-eluting stent fracture and acute coronary syndrome.', Publication Date='Jul, 2009'
# Processing PMID=19530742, Title='Patient-controlled analgesia-related medication errors in the postoperative period: causes and prevention.', Publication Date='Jun, 2009'
# Processing PMID=19406458, Title='Analysis of techniques to secure the renal hilum during laparoscopic donor nephrectomy: review of the FDA database.', Publication Date='May, 2009'
# Processing PMID=19468005, Title='Ambulance stretcher adverse events.', Publication Date='May, 2009'
# Processing PMID=19464444, Title='Analysis of the US Food and Drug Administration Manufacturer and User Facility Device Experience database for adverse events involving Amplatzer septal occluder devices and comparison with the Society of Thoracic Surgery congenital cardiac surgery database.', Publication Date='May, 2009'
# Processing PMID=19322228, Title='The NTI-tss device may be used successfully in the management of bruxism and TMD.', Publication Date='Mar, 2009'
# Processed 510 articles. Data saved.
# Processing PMID=30172248, Title='Medical Bioethics in Dermatologic Procedures.', Publication Date='Mar, 2009'
# Processing PMID=18662411, Title='The NTI-tss device for the therapy of bruxism, temporomandibular disorders, and headache - where do we stand? A qualitative systematic review of the literature.', Publication Date='Jul, 2008'
# Processing PMID=18450857, Title='Adolescent use of insulin and patient-controlled analgesia pump technology: a 10-year Food and Drug Administration retrospective study of adverse events.', Publication Date='May, 2008'
# Processing PMID=18377477, Title='Major complications associated with transcatheter atrial septal occluder implantation: a review of the medical literature and the manufacturer and user facility device experience (MAUDE) database.', Publication Date='Apr, 2008'
# Processing PMID=18372034, Title='Bladder neck contractures related to the use of Hem-o-lok clips in robot-assisted laparoscopic radical prostatectomy.', Publication Date='Mar, 2008'
# Processing PMID=18323318, Title='Epidural conduction device fractures and complications of retained fragments.', Publication Date='Mar, 2008'
# Processing PMID=18312981, Title='A comprehensive review of suburethral sling procedure complications.', Publication Date='Mar, 2008'
# Processing PMID=18303506, Title='Introduction to the MAUDE database.', Publication Date='Feb, 2008'
# Processing PMID=18258157, Title='Form and function of vena cava filters: how do optional filters measure up?', Publication Date='Feb, 2008'
# Processing PMID=18304403, Title='Device failures associated with patient injuries during robot-assisted laparoscopic surgeries: a comprehensive review of FDA MAUDE database.', Publication Date='Feb, 2008'
# Processed 520 articles. Data saved.
# Processing PMID=18090097, Title='Electrode migration after cochlear implantation.', Publication Date='Dec, 2007'
# Processing PMID=17919695, Title='Mechanisms of hemostatic failure during laparoscopic nephrectomy: review of Food and Drug Administration database.', Publication Date='Oct, 2007'
# Processing PMID=17575537, Title='Endotherapy and surgery for GERD.', Publication Date='Aug, 2007'
# Processing PMID=17617499, Title='Adverse events involving intravenous patient-controlled analgesia.', Publication Date='Jul, 2007'
# Processing PMID=17630160, Title='Endometrial ablation devices: review of a manufacturer and user facility device experience database.', Publication Date='Jul, 2007'
# Processing PMID=17599673, Title='Early failure of a small-diameter high-voltage implantable cardioverter-defibrillator lead.', Publication Date='Jun, 2007'
# Processing PMID=17267869, Title='Ethylene vinyl alcohol copolymer erosions after use as a urethral bulking agent.', Publication Date='Feb, 2007'
# Processing PMID=17197707, Title='Severe, diffuse coronary artery spasm after drug-eluting stent placement.', Publication Date='Jan, 2007'
# Processing PMID=17206901, Title='Reported failures of the polymer self-locking (Hem-o-lok) clip: review of data from the Food and Drug Administration.', Publication Date='Jan, 2007'
# Processing PMID=17149713, Title='Presentation and management of major complications of midurethral slings: Are complications under-reported?', Publication Date='Dec, 2006'
# Processed 530 articles. Data saved.
# Processing PMID=17073570, Title='Breast implant surveillance reports to the U.S. Food and Drug Administration: maternal-child health problems.', Publication Date='Nov, 2006'
# Processing PMID=16769279, Title='Emerging endoluminal therapies for gastroesophageal reflux disease: adverse events.', Publication Date='Jun, 2006'
# Processing PMID=16568214, Title='Complications associated with transobturator sling procedures.', Publication Date='Mar, 2006'
# Processing PMID=16036187, Title='Trocar-associated injuries and fatalities: an analysis of 1399 reports to the FDA.', Publication Date='Jul, 2005'
# Processing PMID=15886342, Title='Breast pump adverse events: reports to the food and drug administration.', Publication Date='May, 2005'
# Processing PMID=15851191, Title='Deaths associated with implantable cardioverter defibrillator failure and deactivation reported in the United States Food and Drug Administration Manufacturer and User Facility Device Experience Database.', Publication Date='Apr, 2005'
# Error fetching abstract for PMID 15851191: HTTPSConnectionPool(host='eutils.ncbi.nlm.nih.gov', port=443): Max retries exceeded with url: /entrez/eutils/efetch.fcgi?db=pubmed&id=15851191&rettype=abstract&retmode=xml&email=lhua0420%40gmail.com&api_key=f0b970f706ba8babb0bb582a384964d8b508 (Caused by SSLError(SSLZeroReturnError(6, 'TLS/SSL connection has been closed (EOF) (_ssl.c:1129)')))
# Processing PMID=15805456, Title='Do split-side rails present an increased risk to patient safety?', Publication Date='Apr, 2005'
# Processing PMID=15781766, Title='Cochlear implant complications: utility of federal database in systematic analysis.', Publication Date='Mar, 2005'
# Processing PMID=15781767, Title='The utility of the MAUDE database in researching cochlear implantation complications.', Publication Date='Mar, 2005'
# No abstract found for PMID 15781767 and Title 'The utility of the MAUDE database in researching cochlear implantation complications.'.
# Processing PMID=15525737, Title='Vertebral augmentation and the limits of interpreting complications reported in the food and drug administration manufacturer and user facility device experience database.', Publication Date='Nov, 2004'
# No abstract found for PMID 15525737 and Title 'Vertebral augmentation and the limits of interpreting complications reported in the food and drug administration manufacturer and user facility device experience database.'.
# Processed 540 articles. Data saved.
# Processing PMID=15525736, Title='A review of complications associated with vertebroplasty and kyphoplasty as reported to the Food and Drug Administration medical device related web site.', Publication Date='Nov, 2004'
# Processing PMID=15325606, Title='Surgical stapler-associated fatalities and adverse events reported to the Food and Drug Administration.', Publication Date='Aug, 2004'
# Processing PMID=15121577, Title='Complications associated with global endometrial ablation: the utility of the MAUDE database.', Publication Date='May, 2004'
# No abstract found for PMID 15121577 and Title 'Complications associated with global endometrial ablation: the utility of the MAUDE database.'.
# Processing PMID=15121575, Title='Complications associated with global endometrial ablation: the utility of the MAUDE database.', Publication Date='May, 2004'
# No abstract found for PMID 15121575 and Title 'Complications associated with global endometrial ablation: the utility of the MAUDE database.'.
# Processing PMID=14984183, Title='Endovascular stents: market vigilance and risk factors.', Publication Date='Feb, 2004'
# Processing PMID=14662215, Title='Complications associated with global endometrial ablation: the utility of the MAUDE database.', Publication Date='Dec, 2003'
# Processing PMID=12761003, Title='A retained Racz catheter fragment after epidural neurolysis: implications during magnetic resonance imaging.', Publication Date='May, 2003'
# Processing PMID=12701040, Title='Intra-articular hyaluronans: a review of product-specific safety profiles.', Publication Date='Apr, 2003'
# Processing PMID=12039109, Title='Complications associated with optical-access laparoscopic trocars.', Publication Date='Jun, 2002'
# Processing PMID=11475818, Title='Unexpected ICD pulse generator failure due to electronic circuit damage caused by electrical overstress.', Publication Date='Jul, 2001'
# Processed 550 articles. Data saved.
# Processing PMID=11243287, Title='Impact of FDA advisory on reported vacuum-assisted delivery and morbidity.', Publication Date='Mar, 2001'
# Processing PMID=10642409, Title='Pulmonary artery rupture: serious complication associated with pulmonary artery catheters.', Publication Date='Jan, 2000'
# Processing PMID=30801468, Title='ACOG Committee Opinion No. 769 Summary: Reprocessed Single-Use Devices.', Publication Date='null'
# Processing PMID=30801476, Title='ACOG Committee Opinion No. 769: Reprocessed Single-Use Devices.', Publication Date='null'
# Processing PMID=32217971, Title='Assessing and Adopting New Medical Devices for Obstetric and Gynecologic Care: ACOG Committee Opinion Summary, Number 801.', Publication Date='null'
# Processing PMID=32217977, Title='Assessing and Adopting New Medical Devices for Obstetric and Gynecologic Care: ACOG Committee Opinion, Number 801.', Publication Date='null'
# Processing PMID=34033344, Title='Use and Application Of MAUDE In Patient Safety', Publication Date='null'
# Processing PMID=21249841, Title='Evaluating and Predicting Patient Safety for Medical Devices with
# Integral Information Technology', Publication Date='null'
# Processing PMID=21249804, Title='Making Information Technology a Team Player in Safety: The Case
# of Infusion Devices', Publication Date='null'
# No abstract found for PMID 21249804 and Title 'Making Information Technology a Team Player in Safety: The Case
# of Infusion Devices'.
# All 559 articles have been processed and saved.

# %%
import pandas as pd
from scholarly import scholarly
import time
import os
import sys

def read_output_csv(output_csv):
    """
    读取输出 CSV 文件，并筛选出 Abstract 字段为 "No Abstract Available" 的记录。

    :param output_csv: 输出 CSV 文件的路径
    :return: 包含无摘要记录的 DataFrame
    """
    try:
        df = pd.read_csv(output_csv, encoding='utf-8')
        no_abstract_df = df[df['Abstract'] == "No Abstract Available"]
        return no_abstract_df
    except FileNotFoundError:
        print(f"错误: 文件 '{output_csv}' 未找到。")
        sys.exit(1)
    except Exception as e:
        print(f"读取 '{output_csv}' 时出错: {e}")
        sys.exit(1)

def search_abstract_by_title(title):
    """
    使用 scholarly 库基于标题搜索摘要。

    :param title: 文章标题
    :return: 摘要文本或错误标记
    """
    try:
        search_query = scholarly.search_pubs(title)
        pub = next(search_query, None)
        if pub:
            abstract = pub.get('bib').get('abstract', None)
            if abstract:
                print(f"找到摘要: {abstract[:100]}...")  # 打印摘要的前100个字符
                return abstract
            else:
                print("通过标题搜索未找到摘要。")
                return "No Abstract Available"
        else:
            print("通过标题搜索未找到任何结果。")
            return "No Abstract Available"
    except Exception as e:
        print(f"搜索标题 '{title}' 时出错: {e}")
        return "Error Fetching Abstract by Title"

def update_abstracts(df, output_csv, backup_csv):
    """
    更新 DataFrame 中的 Abstract 字段，并在每次更新后保存回 CSV 文件。

    :param df: 包含无摘要记录的 DataFrame
    :param output_csv: 原始输出 CSV 文件路径
    :param backup_csv: 备份 CSV 文件路径
    :return: 更新后的 DataFrame
    """
    # 创建备份
    if not os.path.exists(backup_csv):
        pd.read_csv(output_csv, encoding='utf-8').to_csv(backup_csv, index=False, encoding='utf-8')
        print(f"已创建备份文件 '{backup_csv}'。")
    else:
        print(f"备份文件 '{backup_csv}' 已存在。")

    # 读取原始 CSV 文件
    try:
        full_df = pd.read_csv(output_csv, encoding='utf-8')
    except Exception as e:
        print(f"读取 '{output_csv}' 时出错: {e}")
        sys.exit(1)

    # 遍历无摘要的记录并更新
    for idx, row in df.iterrows():
        pmid = row['PMID']
        title = row['Title']
        print(f"\n处理 PMID: {pmid}, Title: '{title}'")
        abstract = search_abstract_by_title(title)
        # 更新 DataFrame
        full_df.loc[full_df['PMID'] == pmid, 'Abstract'] = abstract

        # 在每次更新后保存 CSV 文件
        try:
            full_df.to_csv(output_csv, index=False, encoding='utf-8')
            print(f"已更新并保存到 '{output_csv}'。")
        except Exception as e:
            print(f"保存更新到 '{output_csv}' 时出错: {e}")
            sys.exit(1)

        # 暂停以避免触发反爬虫机制
        time.sleep(2)

    return full_df


def main():
    OUTPUT_CSV = "./maude_papers_output.csv"
    BACKUP_CSV = "./maude_papers_output_backup.csv"

    # 读取输出 CSV 并筛选无摘要的记录
    no_abstract_df = read_output_csv(OUTPUT_CSV)
    total_no_abstract = no_abstract_df.shape[0]
    print(f"总共有 {total_no_abstract} 条记录的摘要为 'No Abstract Available'。")

    if total_no_abstract == 0:
        print("所有记录都有摘要。无需进一步操作。")
        return

    # 更新摘要
    updated_df = update_abstracts(no_abstract_df, OUTPUT_CSV, BACKUP_CSV)

    # 统计更新后的结果
    updated_no_abstract = updated_df[updated_df['Abstract'] == "No Abstract Available"].shape[0]
    print(f"\n更新后仍有 {updated_no_abstract} 条记录的摘要为 'No Abstract Available'。")

if __name__ == "__main__":
    main()
# Out:
# 总共有 1 条记录的摘要为 'No Abstract Available'。
# 备份文件 './maude_papers_output_backup.csv' 已存在。
#
# 处理 PMID: 37225596, Title: 'EDITORIAL COMMENT Re: Device Failure and Adverse Events Related to Single-use and Reusable Flexible Ureteroscopes: Findings and New Insights From an 11-Year Analysis of the Manufacturer and User Facility Device Experience Database. Urology. 2023 Jul;177:41-47.'
# 通过标题搜索未找到任何结果。
# 已更新并保存到 './maude_papers_output.csv'。
#
# 更新后仍有 1 条记录的摘要为 'No Abstract Available'。
